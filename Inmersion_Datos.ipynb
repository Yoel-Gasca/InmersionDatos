# %% [markdown]
# # Bienvenido a nuestro primer encuentro de Inmersión de Datos

# %% [markdown]
# ## Clase 01 - Primer colab con Python y pandas

# %% [markdown]
# Importación de datos y contenido de Google Drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importamos los datos de nuestro archivo de Excel o sheets

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %% [markdown]
# Con esta instruccion y con ayuda de la bibioteca Pandas importa los datos de el archivo csv y los almacena en la variable "inmuebles" atravez de la funcion read_csv lee el parametro que es la ruta del archivo y por ultimo se manda llamar la variable junto con la instruccion head para que lea las primeras 5 lineas del documento.

# %% [markdown]
# ### Muestra informacion de nuestro archivo

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %% [markdown]
# Esta pequeña instruccion nos muestra informacion basica del archivo csv como el numero de filas y columnas que conforman este archivo.
# (9520 Filas, 8 columnas)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Esto imprime un arreglo donde se pueden observar los titulos de las columnas de nuestro archivo.
# Como podemos observar en algunos de los titulos de nuestra tabla hay algunos caracteres que pueden causar conflicto a la hora de codificar como puede ser la letra Ñ o los acentos, por elemplo.

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 6539         Casa                    Casa en venta en Usaquén             4
# 4352         Casa         Casa en venta en Zona Noroccidental             3
# 7829  Apartamento                Apartamento en venta en Usme             2
# 4965  Apartamento      Apartamento en venta en Barrios Unidos             3
# 5870  Apartamento           Apartamento en venta en Pasadena              2
# 8746  Apartamento   Apartamento en venta en Chapinero Central             1
# 3056  Apartamento             Apartamento en venta en Kennedy             3
# 4291  Apartamento            Apartamento en venta en Hayuelos             3
# 3594  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 4288  Apartamento             Apartamento en venta en Usaquén             2
#
#       Banos  Area              Barrio                                 UPZ  \
# ...

# %% [markdown]
# Como tal estas instrucciones nos permiten crear un diccionario para los titulos con caracteres especiales y asi poder renombrar los nombres de estos por unos nuevos para que no causen confligto y por ultimo se toma una muestra de los datos con 10 registros aleatorios del documento.

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# Esta instruccion nos muestra toda a informacion acerca de nuestro archivo como el indice, su rango, la estructura, total de columnas que son 8, su orden y sus tipos de cada columna que son objecto como cadenas de texto y numeros enteros y tambien muestra la memoria usada por el archivo

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# Esto nos muestra la informacion del registro numero 300 de nuestra base

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %% [markdown]
# Esto devuelve los datos apartir de la fila 300 hasta la fila 304

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %% [markdown]
# Esto devuelve solo el valor o precio del inmueble de la fila 300

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %% [markdown]
# Esto imprime los valores o precios del rango indicado (300 al 305)

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Esto imprime el promedio del Area de todo el conjunto de datos.

# %%
inmuebles.sample(100)
# Out:
#                      Tipo                                     Descripcion  \
# 9073                 Casa                           Casa en venta en Suba
# 2681                 Casa                       Casa en venta en El Batán
# 5986          Apartamento         Apartamento en venta en Chico Reservado
# 9383                 Casa                        Casa en venta en Kennedy
# 7809                 Casa                     Casa en venta en Tunjuelito
# ...                   ...                                             ...
# 418           Apartamento                Apartamento en venta en Cedritos
# 873                  Casa                           Casa en venta en Bosa
# 5616          Apartamento          Apartamento en venta en Barrios Unidos
# 107   Oficina/Consultorio  Oficina/Consultorio en venta en Ciudad Salitre
# 8767  Oficina/Consultorio        Oficina/Consultorio en venta en El Chicó
#
#       Habitaciones  Banos  Area           Barrio  \
# ...

# %% [markdown]
# Ahora de este resultado de la muestra vamos enfocarnos sobre uno en especifico para explorar sus datos.

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# Esto muestra una serie de falsos y verdaderos donde podemos observar que en el tercer registro ya hay un verdadero asi hasta el final del dataset.

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %% [markdown]
# Esto nos imprime el numero total de inmuebles en venta dentro del barrio Chico Reservado.

# %%
inmueblesChico = (inmuebles.Barrio == 'Chico Reservado')
type(inmueblesChico)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Aqui le indicamos que esa sifra de inmuebles en el barrio de Chico Reservado se va a almacenar dentro de una variable y imprimimos el tipo de dato de la varible nueva.

# %%
chicoReservado = inmuebles[inmueblesChico]
chicoReservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %% [markdown]
# Ahora a partir de la marcara que se genero se crea otra variable con el nombre de chicoReservado para almacenar esa mascara de la variable inmueblesChico y asi despues imprimir los datos de chicoReservado.

# %%
chicoReservado.Area.mean()
# Out:
# 142.78666666666666

# %% [markdown]
# Imprimimos el promedio del area del barrio de Chico Reservado

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %% [markdown]
# Esta función contabiliza el numero de barrios dentro del archivo.

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# Ordena de mayor a menor por numero de inmuebles entre cada uno de los barrios.

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %% [markdown]
# Ahora hacemos lo mismo pero con valor de UPZ

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Con esto generamos un grafico de barras con todos los barrios de bogota

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Con esto solo mostramos en un grafico el conteo en forma decendente tomando los primeros 10 barrios.

# %% [markdown]
# **Desafios:-**
#
# 1- Calcular el promedio de area de todos los inmuebles de los barrios y con base a ese promedio generar un grafico con los primeros 10.

# %%
inmuebles[['Barrio','Area']].groupby(['Barrio']).mean()
# Out:
#                           Area
# Barrio
# Alameda              97.000000
# Alhambra            190.411765
# Andes Norte         124.857143
# Antonio Nariño      163.062500
# Barrancas            70.200000
# ...                        ...
# Villa Maria         207.153846
# Villas De Granada    86.590909
# Villemar             76.888889
# Zona Franca          54.000000
# Zona Noroccidental  135.785633
#
# [149 rows x 1 columns]

# %%
inmuebles[['Barrio','Area']].groupby(['Barrio']).mean().sort_values(by=['Area'], ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# Primero se seleccionan las columnas 'Barrio' y 'Area' inmuebles[['Barrio','Area']] para despues agrupar los datos por la columna 'Barrio' y luego calculando la media (promedio) de las demás columnas para cada grupo de 'Barrio'. Esto nos dará un nuevo DataFrame con la media de 'Area' para cada barrio .groupby(['Barrio']).mean(), seguido de esto  se ordenan en forma descendente basado en los valores de la columna 'Area'.sort_values(by=['Area'], ascending=False), vamos seleccionando las primeras 10 filas de este archivo, lo que nos dará los 10 barrios con el área promedio más grande .head(10) y finalmente, estamos creando un gráfico de barras (bar chart) con estos 10 barrios, donde en el eje X (horizontal) tendrás los nombres de los barrios y en el eje Y (vertical) tendrás los valores del área promedio para cada uno de esos barrios. Esto mostrará visualmente los 10 barrios con el mayor área promedio .plot(kind='bar').

# %% [markdown]
# 2- Consultar otros datos estadisticos como el conteo, mediana, valores mínimo y máximo.

# %% [markdown]
# ## Clase 02 - Tratamiento de Datos y Primeros Gráficos

# %%
inmuebles.sample(5)
# Out:
#              Tipo                           Descripcion  Habitaciones  Banos  \
# 7341  Apartamento  Apartamento en venta en Lago De Suba             3      2
# 2820         Casa           Casa en venta en Tunjuelito             6      4
# 8200  Apartamento      Apartamento en venta en Fontibón             3      2
# 9446  Apartamento       Apartamento en venta en Kennedy             3      1
# 4664  Apartamento      Apartamento en venta en Cedritos             1      2
#
#       Area        Barrio              UPZ          Valor
# 7341    87  Lago De Suba             Suba  $ 380.000.000
# 2820   367    Tunjuelito       Tunjuelito  $ 780.000.000
# 8200    64      Fontibón         Fontibón  $ 240.000.000
# 9446    47       Kennedy  Kennedy Central  $ 140.000.000
# 4664    60      Cedritos          Usaquén  $ 331.000.000

# %% [markdown]
# Como primer paso tomamos una muestra de nuestro Dataset para trabajar sobre esta.

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %% [markdown]
# Este tipo de dato es una cadena de caracteres

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %% [markdown]
# Este resultado se debe a que los valores que estan ingresados como una cadena de texto lo cual hace que pandas lo concadene.

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %% [markdown]
# Loque hace la instruccion split es separar una cadena de texto en funcion de un parametro.

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
type(inmuebles.Valor.str.split())
# Out:
# pandas.core.series.Series

# %% [markdown]
# Loque se hace aqui es devolver un lista de cada elemento

# %%
 inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %% [markdown]
# Devuelve un DataFrame el cual separa el signo de $ de las cantidades de los precios

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                   Descripcion  Habitaciones  Banos  Area  \
# 5428  Apartamento  Apartamento en venta en Bosa             3      1    47
# 4061  Apartamento  Apartamento en venta en Bosa             3      1    42
# 2465         Casa     Casa en venta en Santa Fe            10      2   270
#
#         Barrio                                     UPZ            Valor  \
# 5428      Bosa                            Bosa Central    $ 102.000.000
# 4061      Bosa                            Bosa Central    $ 131.000.000
# 2465  Santa Fe  SANTA FE: Las Nieves + Sagrado Corazón  $ 3.000.000.000
#
#      Moneda         Precio
# 5428      $    102.000.000
# 4061      $    131.000.000
# 2465      $  3.000.000.000

# %% [markdown]
# Esto genera otras 2 columnas donde ya se muestra separados el caracter de el tipo de moneda de la cantidad de los precios, pero todavia no es un numero.

# %%
inmuebles['Precio'] = inmuebles['Precio'].str .replace('.','',regex=True)

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %% [markdown]
# Con esto ya se han eliminado de nuestros precios el punto

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Pero aun lo sigue identificando como un objeto.

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %% [markdown]
# Con esto agregamos otra columna que es de tipo flotante la cual contendra las cifras numericas que se le indiquen.

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %% [markdown]
# Esto nos devuelve otros para metros estadisticos como el conteo de filas, el promedio, el desvio estandar, valor minimo, la mediama y el valor maximo.

# %%
 pd.set_option('display.precision',2)
 pd.set_option('display.float_format', lambda x: '%.2f' % x)
 inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# Esta funcion sirvio para restar las cifras despues de los puntos decimales en el anterior ejemplo.

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %% [markdown]
# Como se pudo observar en la tabla hay un inmueble que contiene 110 habitaciones, lo que con la instruccion loc sirve para localizar un dato en especifico para ver si hay algun error en la notacion.

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Esto visualiza un grafico de histograma para entender la frecuencia de una variable donde podemos observar que la gran consentracion de precios de los inmuebles esta entre los 0 a los 2000 millones de pesos colombianos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribucion de valores de inmuebles en Bogota')
plt.xlim((50,1000))
plt.savefig('/content/drive/MyDrive/Inmersion-de-Datos-Alura/valorInmuebles.png', format='png')
plt.show()

# %% [markdown]
# Para una mejor interpretacion de un grafico vamos a importar 2 bibliotecas que permiten leer mas caramente un grafico las cuales son matplotlib y seaborn que ofrecen una variedad mas extensa de varios tipos de graficos.
#
# Despues se dibujaria el lienzo para el grafico (plt.figure(figsize=(10,6))) y luego asignar un grafico de histograma con una curva de densidad de los valores de los datos de los inmuebles en los precios y el tipo a una variable, para despues colocarle un titulo a nuestro gragico y por ultimo colocar un limite entre los precios de los inmuebles de rango de 50 a 1000 millones y guardar una imagen gel d¿grafico en la ubicacion que se le indique, para despues reflejarlo de una manera mas entendible en el grafico.

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribucion de valores de inmuebles en Bogota')
plt.xlim((50,1000))
plt.ylim((0,20))
plt.savefig('/content/drive/MyDrive/Inmersion-de-Datos-Alura/valorInmuebles2.png', format='png')
plt.show()

# %% [markdown]
# Con esto podemos hacer una especie de zoom al grafico para ver mas a detalle y ver la cantidad y los valores de oficinas, locales, lotes, bodegas, etc.

# %% [markdown]
# **Desafios**
#
# 1- Estudiar a fondo el histograma, seleccionar 3 tipos de inmuebles y estilizar de mejor manera el grafico con titulos, aumentar el tamaño del label, conclucion de la información.

# %%
tiposInmueblesSelect = ['Oficina/Consultorio', 'Edificio', 'Lote']
inmueblesSeleccionados = inmuebles[inmuebles['Tipo'].isin(tiposInmueblesSelect)]

plt.figure(figsize=(12,7))
grafica = sns.histplot(data=inmueblesSeleccionados, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Valores de los inmuebles seleccionados')
plt.show()

# %% [markdown]
# Se lececionaron tres tipos de inmueble de los ya existentes y fuefon almacenads den una variable llamada 'tiposInmueblesSelect'
#
# En 'inmueblesSeleccionados' se filtraron los inmuebles seleccionando aquellos cuyo tipo está en la lista 'tiposInmueblesSelect'.
#
# Se crea una nueva figura para la gráfica con un tamaño específico. Tambien se Crea un histograma con una distribución de kernel (kde) utilizando los datos de 'inmueblesSeleccionados'.
# Los datos se representan en el eje X utilizando la columna 'Precio_Millon' y se diferencian por el color según el tipo en el eje Y.
#
# Se asigna un nuevo titulo ala grafica y se muestra el grafico.

# %% [markdown]
# 2- Reflegar el precio por metro cuadrado y reprensentarlo con un grafico que se adapte a esta demostracion.

# %%
inmuebles['Precio_m2'] = inmuebles.Precio_Millon / inmuebles.Area

# %%
datoStd = inmuebles.groupby(by = 'Barrio').describe()

topPromM2 = datoStd.Precio_m2[['mean', 'std']].sort_values(by= 'mean', ascending=False).head(10)
topPromM2 = topPromM2.reset_index()

# %%
sns.set_theme()
plt.figure(figsize = (12,6))

sns.barplot(data = topPromM2, y = 'mean', x='Barrio')

sigma = topPromM2['std']

x = topPromM2['Barrio']
y = topPromM2['mean']

plt.errorbar(x = x, y = y, yerr=(sigma, sigma), fmt='none', color='k', capsize=5)

plt.title('Costo por m2 de inmuebles por barrio')
plt.xlabel('Barrio')
plt.ylabel('Promedio')

plt.xticks(rotation = 80)
plt.savefig('/content/drive/MyDrive/Inmersion-de-Datos-Alura/costoPorM2', format = 'png')
plt.show()

# %% [markdown]
# Primero de creo la columna con el valor por m2
#
# Para despues agrupar y usar describe para obtener el promedio y la desviación estándar
#
# Luego se generaria el grafico. Se uso barplot y tambien se agregaron barras de error usando la desviación estándar.

# %% [markdown]
# ## Clase 03 - Profundizando el análisis exploratorio

# %%
inmuebles.groupby('Barrio').mean()
# Out:
# <ipython-input-48-7fb844af9b3c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmuebles.groupby('Barrio').mean()
#                     Habitaciones  Banos   Area  Precio_Millon  Precio_m2
# Barrio
# Alameda                     3.00   2.00  97.00         580.00       5.98
# Alhambra                    3.00   2.94 190.41         752.35       4.33
# Andes Norte                 3.00   2.86 124.86         709.57       6.05
# Antonio Nariño              4.31   2.50 163.06         459.22       3.53
# Barrancas                   2.87   2.13  70.20         314.13       4.42
# ...                          ...    ...    ...            ...        ...
# Villa Maria                 4.69   3.69 207.15         402.85       2.04
# Villas De Granada           3.45   2.32  86.59         282.30       3.17
# ...

# %% [markdown]
# Para profunddizar mas en los datos se han agrupado todos los barrios de la ciudad para reflejar el promedio de todas las columnas numericas de todos los barrios.

# %%
datosBarrio = inmuebles.groupby('Barrio').sum()
datosBarrio
# Out:
# <ipython-input-49-22e159edde3f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datosBarrio = inmuebles.groupby('Barrio').sum()
#                     Habitaciones  Banos    Area  Precio_Millon  Precio_m2
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00      73.56
# Andes Norte                   21     20     874        4967.00      42.35
# Antonio Nariño               207    120    7827       22042.65     169.47
# Barrancas                     43     32    1053        4712.00      66.24
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00      26.58
# ...

# %% [markdown]
# Ahora tomamos todos los datos por barrio y sumamos cada uno de sus atributos y con base a estos datos se obtendra acontinuacion el promedio.

# %%
datosBarrio['Valor_m2_Barrio'] = datosBarrio['Precio_Millon']/datosBarrio['Area']
datosBarrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  Precio_m2  \
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00      73.56
# Andes Norte                   21     20     874        4967.00      42.35
# Antonio Nariño               207    120    7827       22042.65     169.47
# Barrancas                     43     32    1053        4712.00      66.24
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00      26.58
# Villas De Granada             76     51    1905        6210.62      69.71
# Villemar                      53     37    1384        5469.00      71.81
# Zona Franca                    2      1      54         160.00       2.96
# Zona Noroccidental          2778   2204  119084      544453.06    4049.16
#
#                     Valor_m2_Barrio
# Barrio
# ...

# %% [markdown]
# Aqui obtenemos el valor por metro cuadrado con respecto al promedio del propio barrio que es el resultado de la suma de todos los precios de un barrio y dividirlo entre los metros cuadrados de ese barrio.

# %%
dict(datosBarrio['Valor_m2_Barrio'])
# Out:
# {'Alameda': 5.979381443298969,
#  'Alhambra': 3.95118937287612,
#  'Andes Norte': 5.683066361556064,
#  'Antonio Nariño': 2.816232272901495,
#  'Barrancas': 4.4748338081671415,
#  'Barrios Unidos': 2.9599171141243064,
#  'Bella Suiza': 6.2905507012394,
#  'Bellavista Occidental': 2.522711390635919,
#  'Bochica': 3.4078212290502794,
#  'Bogotá D.C': 5.212760277629472,
#  'Bosa': 2.6778451358697213,
#  'Bosa Piamonte': 1.175,
#  'Bosa Porvenir': 3.1666666666666665,
#  'Bosque De Pinos': 6.046475195822455,
#  'Bosque Popular': 3.864097363083164,
#  'Boyaca ': 2.637421499815294,
#  'Buenos Aires': 2.6,
#  'Candelaria La Nueva': 4.0625,
#  'Cantagallo': 5.71920581655481,
#  'Capellania': 4.316791690709752,
#  'Casablanca': 6.245421245421245,
#  'Castilla': 3.4035893155258763,
#  'Cedritos': 5.027419586695463,
#  'Cerros De Suba': 6.202830188679245,
#  'Chapinero': 4.58018576602501,
#  'Chapinero Alto': 6.4239336492891,
#  'Chapinero Central': 6.360286919831224,
# ...

# %% [markdown]
# Pocedente de esto se genera un diccionario donde se almacenan los nuevos valores

# %%
m2Barrio = dict(datosBarrio['Valor_m2_Barrio'])

# %% [markdown]
# Estos datos se almacenan en una nueva variable.

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2Barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Precio_m2  \
# ...

# %% [markdown]
# Los datos de este diccionario son una llave que son asignados a una nueva columna en el dataset teniendo una nueva referencia la cual es el valor por metro cuadrado de cada inmueble.

# %%
inmuebles['Barrio'].value_counts()[:10].index
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %% [markdown]
# Esta intruccion nos muestra una serie donde podemos observar a los 10 barrios con mas inmuebles en venta.

# %%
topBarrios = inmuebles['Barrio'].value_counts()[:10].index

# %% [markdown]
# Con base en estos datos se crea una variable que contiene los indices.

# %%
datosBarrio.reset_index(inplace=True)
datosBarrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2  Valor_m2_Barrio
# 0         5.98             5.98
# 1        73.56             3.95
# 2        42.35             5.68
# ...

# %% [markdown]
# Con esta instruccion se resetea barrios y se convierte en una columna.

# %%
datosBarrio.query('Barrio in @topBarrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2  Valor_m2_Barrio
# 5      2070.61             2.96
# 10     1654.36             2.68
# 22     2853.23             5.03
# 24     2466.03             4.58
# 50     1795.71             2.89
# ...

# %% [markdown]
# Esta es una consulta que devuelve los datos de los 10 barrios con mas inmuebles en venta.

# %%
plt.figure(figsize=(13,8))
ax = sns.barplot(x='Barrio', y='Valor_m2_Barrio', data = datosBarrio.query('Barrio in @topBarrios'))
ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# Generamos un grafico con los datos de la consulta.

# %%
plt.figure(figsize=(13,8))
ax = sns.boxplot(x='Barrio', y='Valor_m2_Barrio', data = datosBarrio.query('Barrio in @topBarrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Aqui generamos un grafico conocido como boxplot pero con los parametros del area.

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Precio_Millon', data = inmuebles.query('Barrio in @topBarrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Este tipo de grafico se observan valores minimos y maximos lo que indica que porcentaje de los valores por metro cuadrado de los precios por millon de cada barrio.

# %%
plt.figure(figsize=(13,7))
ax = sns.boxplot(x='Barrio', y='Precio_Millon', data = inmuebles.query('Barrio in @topBarrios & Precio_Millon < 1500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Al agregar la condicion que 'Precio_Millon' sea menor que 1500 hace que se eliminen los valores inexistentes de nuestro grafico y poderlo apreciar mejor.

# %%
plt.figure(figsize=(11,7))
ax = sns.boxplot(x='Barrio', y='Area', data = inmuebles.query('Barrio in @topBarrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Aplicamos el mismo grafico pero ahora con el 'Area'
#
# Los graficos de cajas permiten comparar dentro de una misma variable diferentes conjuntos de datos para obtener una conclución mas eficiente sobre la informacion que se esta manejando.

# %% [markdown]
# ### Nuevas Variables
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
datosRaw = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Identificación (Capítulo A).csv', sep=';', encoding='latin-1')
datosRaw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %% [markdown]
# De esta forma se extraen los datos del nuevo archivo csv que se descargo.

# %%
datosRaw.shape
# Out:
# (106467, 11)

# %% [markdown]
# El archivo esta compuesto por 106467 filas y 11 columnas.

# %%
datosRaw = datosRaw.loc[datosRaw.MPIO == 11001]

# %% [markdown]
# Localizamos un elemento en especifico.

# %%
datosB = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Datos de la vivenda y su entorno (Capítulo B).csv', sep=';', encoding='latin-1')
datosC = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Condiciones habitacionales del hogar (Capítulo C).csv', sep=';', encoding='latin-1')
datosE = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Composición del hogar y demografía (Capítulo E).csv', sep=';', encoding='latin-1')
datosH = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Educación (Capitulo H).csv', sep=';', encoding='latin-1')
datosL = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep=';', encoding='latin-1')
datosK = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Fuerza de trabajo (Capítulo K).csv', sep=';', encoding='latin-1')
# Out:
# <ipython-input-109-2d5501037cb2>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datosC = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Condiciones habitacionales del hogar (Capítulo C).csv', sep=';', encoding='latin-1')
# <ipython-input-109-2d5501037cb2>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datosE = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Composición del hogar y demografía (Capítulo E).csv', sep=';', encoding='latin-1')
# <ipython-input-109-2d5501037cb2>:4: DtypeWarning: Columns (26,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datosH = pd.read_csv('/content/drive/MyDrive/Inmersion-de-Datos-Alura/Educación (Capitulo H).csv', sep=';', encoding='latin-1')
# ...

# %% [markdown]
# Importamos mas datos de otros archivos.

# %%
datosDane = pd.merge(datosRaw,datosB,on='DIRECTORIO', how='left')
datosDane.shape
# Out:
# (86504, 73)

# %% [markdown]
# Aqui se fusionan los datos de las varirables señaladas y ahora nuestro archivo contiene 73 columnas.

# %%
datosDane = pd.merge(datosDane,datosC,on='DIRECTORIO', how='left')
datosDane = pd.merge(datosDane,datosE,on='DIRECTORIO', how='left')

datosDane.shape
# Out:
# <ipython-input-111-a88f0f5f7e3d>:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datosDane = pd.merge(datosDane,datosE,on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datosDane.shape
# Out:
# (238559, 281)

# %% [markdown]
# Con esto generamos mas columnas de informacion en el Dataset.
